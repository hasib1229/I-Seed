# %%
import pandas as pd
import json
import os

# %%
dataset_json_path = "data/Original-I-Seed-Photo/Artificial_Seed_Test_Set.v8i.coco/test/_annotations.coco.json"
result_json_path = "runs/predict/exp31/result.json"
custom_blue_json_dir_path = "/home/yanuar/Desktop/Json/Blue/"
custom_blue__param_json_dir_path = "/home/yanuar/Desktop/Json/Blue/Parameter/"
custom_org_json_dir_path = "/home/yanuar/Desktop/Json/Org/"
custom_org__param_json_dir_path = "/home/yanuar/Desktop/Json/Org/Parameter/"
if not os.path.exists(custom_blue_json_dir_path):
    os.mkdir(custom_blue_json_dir_path)
if not os.path.exists(custom_org_json_dir_path):
    os.mkdir(custom_org_json_dir_path)
if not os.path.exists(custom_blue__param_json_dir_path):
    os.mkdir(custom_blue__param_json_dir_path)
if not os.path.exists(custom_org__param_json_dir_path):
    os.mkdir(custom_org__param_json_dir_path)

# %%
# Getting the data you have
with open(dataset_json_path) as f:
    data_annot = json.load(f)
    
with open(result_json_path) as f:
    data_res = json.load(f)

# %%
# The annotation key
annot = pd.DataFrame(data_annot['annotations'])
annot_blue = annot.query('category_id == 0')
annot_org = annot.query('category_id == 1')

# %%
# Indexes used to merge
idxes_blue = annot_blue['image_id']
idxes_org = annot_org['image_id']

# %%
# images key 
images = pd.DataFrame(data_annot['images'])
img_blue = images[images['id'].isin(idxes_blue)]
img_org = images[images['id'].isin(idxes_org)]

# %%
# Exporting data for class blue
blue_out = data_annot.copy()
blue_out['annotations'] = list(annot_blue.T.to_dict().values())
blue_out['images'] = list(img_blue.T.to_dict().values())
with open(custom_blue_json_dir_path+"Blue_annot(Class 0).json", 'w') as f:
    f.write(json.dumps(blue_out))
f.close()

# %%
# Exporting data for class Original
org_out = data_annot.copy()
org_out['annotations'] = list(annot_org.T.to_dict().values())
org_out['images'] = list(img_org.T.to_dict().values())
with open(custom_org_json_dir_path+"Org_annot(Class 1).json", 'w') as f:
    f.write(json.dumps(org_out))
f.close()

# %%
# Separate them
data_res = pd.DataFrame(data_res)
blue = data_res.query('category_id == 0')
org = data_res.query('category_id == 1')

# %%
# Exporting results data for class blue
blue_res = list(blue.T.to_dict().values())
with open(custom_blue_json_dir_path+"Blue_Results(Class 0).json", 'w') as f:
    f.write(json.dumps(blue_res))
f.close()

# %%
# Exporting results data for class original
org_res = list(org.T.to_dict().values())
with open(custom_org_json_dir_path+"Org_Results(Class 1).json", 'w') as f:
    f.write(json.dumps(org_res))
f.close()

# %%
def extract_data(file_path, result_path, output_dir):
    '''
    This Function takes two major arguments, file path and the number of the parameter
    '''
    # Importing and Preparing Data
    import pandas as pd
    import numpy as np
    import json
    with open (file_path, 'r') as f:
        ground_truth = json.load(f)
        
        
    # Dict Keys and DataFrames
    info_table = ground_truth['info']
    licenses_table = ground_truth['licenses']
    categories_table = ground_truth['categories']
    images_table = pd.DataFrame(ground_truth['images'])
    annotations = pd.DataFrame(ground_truth['annotations'])
    outputs = {}
    
    images_table['shorten_name'] = images_table['file_name'].str.extract(r'^(\D\D_\d\d?m_\D\D).*')
    file_names = list(set(images_table['shorten_name'].unique()))
    
    for file_name in file_names:
        outputs[file_name] = {"info": info_table, "licenses":licenses_table, "categories":categories_table}
        
    # Separate the files
    images_per_file = {}
    for file_name in file_names:
        mask = np.column_stack([images_table['shorten_name'].str.contains(file_name, na=False)])
        images_per_file[file_name] = images_table.loc[mask.any(axis=1)]
        images_per_file[file_name].drop('shorten_name', axis=1, inplace=True)
    
    images_per_file_backup = images_per_file.copy()
    # Separate annotations
    fulls_per_file = {}
    for file_name in file_names:
        full_df = images_per_file[file_name].merge(annotations, left_on=['id'], right_on=['image_id'])
        full_df.drop(['id_x'], axis=1, inplace=True)
        full_df['id'] = full_df['id_y']
        full_df.drop(['id_y'], axis=1, inplace=True)
        fulls_per_file[file_name] = full_df.copy()
        
    
    # The wanted Annotations after separation
    annots_per_file = {}
    for file_name in file_names:
        annots_per_file[file_name] = fulls_per_file[file_name][annotations.columns]
        
    # Converting them to list of dicts
    for file_name in file_names:
        images_per_file[file_name] = images_per_file[file_name].T.to_dict().values()
        annots_per_file[file_name] = annots_per_file[file_name].T.to_dict().values()
    
    # The Whole Two Files
    for file_name in file_names:
        outputs[file_name]["images"] = list(images_per_file[file_name])
        outputs[file_name]["annotations"] = list(annots_per_file[file_name])
        
    # Exporting
    for file_name in file_names:
        with open(output_dir+file_name+".json", 'w') as f:
            f.write(json.dumps(outputs[file_name]))
            f.close()



    # Results Part
    if result_path != None:
        res = pd.read_json(result_path)
        for file_name in file_names:
            cur_full = images_per_file_backup[file_name].merge(res, left_on=['id'], right_on=['image_id'])
            cur_res = list(cur_full[res.columns].T.to_dict().values())

            with open(output_dir+f"Results_{file_name}.json", 'w') as f:
                f.write(json.dumps(cur_res))
                f.close()

# %%
extract_data(dataset_json_path, result_json_path, '/home/yanuar/Desktop/Json/Whole/Parameter/')

# %%
extract_data(custom_blue_json_dir_path+"Blue_annot(Class 0).json", 'Results/Visualization/Data_Parsing/Blue_Results(Class 0).json', custom_blue__param_json_dir_path)
# Out:
# /home/yanuar/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
extract_data(custom_org_json_dir_path+'Org_annot(Class 1).json', 'Results/Visualization/Data_Parsing/Org_Results(Class 1).json',custom_org__param_json_dir_path)
# Out:
# /home/yanuar/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
import itertools
import json
import warnings
from collections import OrderedDict
from pathlib import Path
from typing import List, Union

import fire
import numpy as np
from terminaltables import AsciiTable


def _cocoeval_summarize(
    cocoeval, ap=1, iouThr=None, catIdx=None, areaRng="all", maxDets=100, catName="", nameStrLen=None
):
    p = cocoeval.params
    if catName:
        iStr = " {:<18} {} {:<{nameStrLen}} @[ IoU={:<9} | area={:>6s} | maxDets={:>3d} ] = {:0.3f}"
        nameStr = catName
    else:
        iStr = " {:<18} {} @[ IoU={:<9} | area={:>6s} | maxDets={:>3d} ] = {:0.3f}"
    titleStr = "Average Precision" if ap == 1 else "Average Recall"
    typeStr = "(AP)" if ap == 1 else "(AR)"
    iouStr = "{:0.2f}:{:0.2f}".format(p.iouThrs[0], p.iouThrs[-1]) if iouThr is None else "{:0.2f}".format(iouThr)

    aind = [i for i, aRng in enumerate(p.areaRngLbl) if aRng == areaRng]
    mind = [i for i, mDet in enumerate(p.maxDets) if mDet == maxDets]
    if ap == 1:
        # dimension of precision: [TxRxKxAxM]
        s = cocoeval.eval["precision"]
        # IoU
        if iouThr is not None:
            t = np.where(iouThr == p.iouThrs)[0]
            s = s[t]
        if catIdx is not None:
            s = s[:, :, catIdx, aind, mind]
        else:
            s = s[:, :, :, aind, mind]
    else:
        # dimension of recall: [TxKxAxM]
        s = cocoeval.eval["recall"]
        if iouThr is not None:
            t = np.where(iouThr == p.iouThrs)[0]
            s = s[t]
        if catIdx is not None:
            s = s[:, catIdx, aind, mind]
        else:
            s = s[:, :, aind, mind]
    if len(s[s > -1]) == 0:
        mean_s = -1
    else:
        mean_s = np.mean(s[s > -1])
    if catName:
        print(iStr.format(titleStr, typeStr, nameStr, iouStr, areaRng, maxDets, mean_s, nameStrLen=nameStrLen))
    else:
        print(iStr.format(titleStr, typeStr, iouStr, areaRng, maxDets, mean_s))
    return mean_s


def evaluate_core(
    dataset_path,
    result_path,
    metric: str = "bbox",
    classwise: bool = False,
    max_detections: int = 500,
    iou_thrs=None,
    metric_items=None,
    out_dir: str = None,
    areas: List[int] = [1024, 9216, 10000000000],
    COCO=None,
    COCOeval=None,
):
    """Evaluation in COCO protocol.
    Args:
        dataset_path (str): COCO dataset json path.
        result_path (str): COCO result json path.
        metric (str | list[str]): Metrics to be evaluated. Options are
            'bbox', 'segm', 'proposal'.
        classwise (bool): Whether to evaluating the AP for each class.
        max_detections (int): Maximum number of detections to consider for AP
            calculation.
            Default: 500
        iou_thrs (List[float], optional): IoU threshold used for
            evaluating recalls/mAPs. If set to a list, the average of all
            IoUs will also be computed. If not specified, [0.50, 0.55,
            0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95] will be used.
            Default: None.
        metric_items (list[str] | str, optional): Metric items that will
            be returned. If not specified, ``['AR@10', 'AR@100',
            'AR@500', 'AR_s@500', 'AR_m@500', 'AR_l@500' ]`` will be
            used when ``metric=='proposal'``, ``['mAP', 'mAP50', 'mAP75',
            'mAP_s', 'mAP_m', 'mAP_l', 'mAP50_s', 'mAP50_m', 'mAP50_l']``
            will be used when ``metric=='bbox' or metric=='segm'``.
        out_dir (str): Directory to save evaluation result json.
        areas (List[int]): area regions for coco evaluation calculations
    Returns:
        dict:
            eval_results (dict[str, float]): COCO style evaluation metric.
            export_path (str): Path for the exported eval result json.
    """

    metrics = metric if isinstance(metric, list) else [metric]
    allowed_metrics = ["bbox", "segm"]
    for metric in metrics:
        if metric not in allowed_metrics:
            raise KeyError(f"metric {metric} is not supported")
    if iou_thrs is None:
        iou_thrs = np.linspace(0.5, 0.95, int(np.round((0.95 - 0.5) / 0.05)) + 1, endpoint=True)
    if metric_items is not None:
        if not isinstance(metric_items, list):
            metric_items = [metric_items]
    if areas is not None:
        assert (
            len(areas) == 3
        ), "3 integers should be specified as areas, \
            representing 3 area regions"

    eval_results = OrderedDict()
    cocoGt = COCO(dataset_path)
    cat_ids = list(cocoGt.cats.keys())
    for metric in metrics:
        msg = f"Evaluating {metric}..."
        msg = "\n" + msg
        print(msg)

        iou_type = metric
        with open(result_path) as json_file:
            results = json.load(json_file)
        try:
            if iou_type == "segm":
                # Refer to https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocotools/coco.py#L331  # noqa
                # When evaluating mask AP, if the results contain bbox,
                # cocoapi will use the box area instead of the mask area
                # for calculating the instance area. Though the overall AP
                # is not affected, this leads to different
                # small/medium/large mask AP results.
                for x in results:
                    x.pop("bbox")
                warnings.simplefilter("once")
                warnings.warn(
                    'The key "bbox" is deleted for more accurate mask AP '
                    "of small/medium/large instances since v2.12.0. This "
                    "does not change the overall mAP calculation.",
                    UserWarning,
                )
            cocoDt = cocoGt.loadRes(results)
        except IndexError:
            print("The testing results of the whole dataset is empty.")
            break

        cocoEval = COCOeval(cocoGt, cocoDt, iou_type)
        if areas is not None:
            cocoEval.params.areaRng = [
                [0 ** 2, areas[2]],
                [0 ** 2, areas[0]],
                [areas[0], areas[1]],
                [areas[1], areas[2]],
            ]
        cocoEval.params.catIds = cat_ids
        cocoEval.params.maxDets = [max_detections]
        cocoEval.params.iouThrs = (
            [iou_thrs] if not isinstance(iou_thrs, list) and not isinstance(iou_thrs, np.ndarray) else iou_thrs
        )
        # mapping of cocoEval.stats
        coco_metric_names = {
            "mAP": 0,
            "mAP75": 1,
            "mAP50": 2,
            "mAP_s": 3,
            "mAP_m": 4,
            "mAP_l": 5,
            "mAP50_s": 6,
            "mAP50_m": 7,
            "mAP50_l": 8,
            "AR_s": 9,
            "AR_m": 10,
            "AR_l": 11,
        }
        if metric_items is not None:
            for metric_item in metric_items:
                if metric_item not in coco_metric_names:
                    raise KeyError(f"metric item {metric_item} is not supported")

        cocoEval.evaluate()
        cocoEval.accumulate()
        # calculate mAP50_s/m/l
        mAP = _cocoeval_summarize(cocoEval, ap=1, iouThr=None, areaRng="all", maxDets=max_detections)
        mAP50 = _cocoeval_summarize(cocoEval, ap=1, iouThr=0.5, areaRng="all", maxDets=max_detections)
        mAP75 = _cocoeval_summarize(cocoEval, ap=1, iouThr=0.75, areaRng="all", maxDets=max_detections)
        mAP50_s = _cocoeval_summarize(cocoEval, ap=1, iouThr=0.5, areaRng="small", maxDets=max_detections)
        mAP50_m = _cocoeval_summarize(cocoEval, ap=1, iouThr=0.5, areaRng="medium", maxDets=max_detections)
        mAP50_l = _cocoeval_summarize(cocoEval, ap=1, iouThr=0.5, areaRng="large", maxDets=max_detections)
        mAP_s = _cocoeval_summarize(cocoEval, ap=1, iouThr=None, areaRng="small", maxDets=max_detections)
        mAP_m = _cocoeval_summarize(cocoEval, ap=1, iouThr=None, areaRng="medium", maxDets=max_detections)
        mAP_l = _cocoeval_summarize(cocoEval, ap=1, iouThr=None, areaRng="large", maxDets=max_detections)
        AR_s = _cocoeval_summarize(cocoEval, ap=0, iouThr=None, areaRng="small", maxDets=max_detections)
        AR_m = _cocoeval_summarize(cocoEval, ap=0, iouThr=None, areaRng="medium", maxDets=max_detections)
        AR_l = _cocoeval_summarize(cocoEval, ap=0, iouThr=None, areaRng="large", maxDets=max_detections)
        cocoEval.stats = np.append(
            [mAP, mAP75, mAP50, mAP_s, mAP_m, mAP_l, mAP50_s, mAP50_m, mAP50_l, AR_s, AR_m, AR_l], 0
        )

        if classwise:  # Compute per-category AP
            # Compute per-category AP
            # from https://github.com/facebookresearch/detectron2/
            precisions = cocoEval.eval["precision"]
            # precision: (iou, recall, cls, area range, max dets)
            assert len(cat_ids) == precisions.shape[2]

            max_cat_name_len = 0
            for idx, catId in enumerate(cat_ids):
                nm = cocoGt.loadCats(catId)[0]
                cat_name_len = len(nm["name"])
                max_cat_name_len = cat_name_len if cat_name_len > max_cat_name_len else max_cat_name_len

            results_per_category = []
            for idx, catId in enumerate(cat_ids):
                # skip if no image with this category
                image_ids = cocoGt.getImgIds(catIds=[catId])
                if len(image_ids) == 0:
                    continue
                # area range index 0: all area ranges
                # max dets index -1: typically 100 per image
                nm = cocoGt.loadCats(catId)[0]
                ap = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    catIdx=idx,
                    areaRng="all",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap_s = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    catIdx=idx,
                    areaRng="small",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap_m = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    catIdx=idx,
                    areaRng="medium",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap_l = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    catIdx=idx,
                    areaRng="large",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap50 = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    iouThr=0.5,
                    catIdx=idx,
                    areaRng="all",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap50_s = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    iouThr=0.5,
                    catIdx=idx,
                    areaRng="small",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap50_m = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    iouThr=0.5,
                    catIdx=idx,
                    areaRng="medium",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                ap50_l = _cocoeval_summarize(
                    cocoEval,
                    ap=1,
                    iouThr=0.5,
                    catIdx=idx,
                    areaRng="large",
                    maxDets=max_detections,
                    catName=nm["name"],
                    nameStrLen=max_cat_name_len,
                )
                results_per_category.append((f'{metric}_{nm["name"]}_mAP', f"{float(ap):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP_s', f"{float(ap_s):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP_m', f"{float(ap_m):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP_l', f"{float(ap_l):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP50', f"{float(ap50):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP50_s', f"{float(ap50_s):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP50_m', f"{float(ap50_m):0.3f}"))
                results_per_category.append((f'{metric}_{nm["name"]}_mAP50_l', f"{float(ap50_l):0.3f}"))

            num_columns = min(6, len(results_per_category) * 2)
            results_flatten = list(itertools.chain(*results_per_category))
            headers = ["category", "AP"] * (num_columns // 2)
            results_2d = itertools.zip_longest(*[results_flatten[i::num_columns] for i in range(num_columns)])
            table_data = [headers]
            table_data += [result for result in results_2d]
            table = AsciiTable(table_data)
            print("\n" + table.table)

        if metric_items is None:
            metric_items = ["mAP", "mAP50", "mAP75", "mAP_s", "mAP_m", "mAP_l", "mAP50_s", "mAP50_m", "mAP50_l"]

        for metric_item in metric_items:
            key = f"{metric}_{metric_item}"
            val = float(f"{cocoEval.stats[coco_metric_names[metric_item]]:.3f}")
            eval_results[key] = val
        ap = cocoEval.stats
        eval_results[f"{metric}_mAP_copypaste"] = (
            f"{ap[0]:.3f} {ap[1]:.3f} {ap[2]:.3f} {ap[3]:.3f} "
            f"{ap[4]:.3f} {ap[5]:.3f} {ap[6]:.3f} {ap[7]:.3f} "
            f"{ap[8]:.3f}"
        )
        if classwise:
            eval_results["results_per_category"] = {key: value for key, value in results_per_category}
    # set save path
    if not out_dir:
        out_dir = Path(result_path).parent
        print(out_dir)
    print(dataset_path)
    Path(out_dir).mkdir(parents=True, exist_ok=True)
    eval_path = str(out_dir)+"/"+"eval"
    Path(eval_path).mkdir(parents=True, exist_ok=True)
    export_path = str("eval_"+os.path.basename(dataset_path)) # I'm the code wanted to adjust
    print("Export path" + export_path)
    # export as json
    with open((str(eval_path)+"/"+export_path), "w", encoding="utf-8") as outfile:
        print(export_path)
        json.dump(eval_results, outfile, indent=4, separators=(",", ":"))
    print("COCO evaluation results are successfully exported to {}".format(str(out_dir)+"/"+export_path))
    return {"eval_results": eval_results, "export_path": export_path}


def evaluate(
    dataset_json_path: str,
    result_json_path: str,
    out_dir: str = None,
    type: str = "bbox",
    classwise: bool = False,
    max_detections: int = 500,
    iou_thrs: Union[List[float], float] = None,
    areas: List[int] = [1024, 9216, 10000000000],
    return_dict: bool = False,
):
    """
    Args:
        dataset_json_path (str): file path for the coco dataset json file
        result_json_path (str): file path for the coco result json file
        out_dir (str): dir to save eval result
        type (bool): 'bbox' or 'segm'
        classwise (bool): whether to evaluate the AP for each class
        max_detections (int): Maximum number of detections to consider for AP alculation. Default: 500
        iou_thrs (float): IoU threshold used for evaluating recalls/mAPs
        areas (List[int]): area regions for coco evaluation calculations
        return_dict (bool): If True, returns a dict with 'eval_results' 'export_path' fields.
    """
    try:
        from pycocotools.coco import COCO
        from pycocotools.cocoeval import COCOeval
    except ModuleNotFoundError:
        raise ModuleNotFoundError(
            'Please run "pip install -U pycocotools" ' "to install pycocotools first for coco evaluation."
        )

    # perform coco eval
    result = evaluate_core(
        dataset_json_path,
        result_json_path,
        type,
        classwise,
        max_detections,
        iou_thrs,
        out_dir=out_dir,
        areas=areas,
        COCO=COCO,
        COCOeval=COCOeval,
    )
    if return_dict:
        return result

# %%
import os
results = []
files = []
for filename in os.listdir('/home/yanuar/Desktop/Json/Blue/Main_Parameter'):
    if "Results" == filename[:7]:
        results.append(filename)
    else:
        files.append(filename)
        
for file in files:
    evaluate('/home/yanuar/Desktop/Json/Blue/Main_Parameter/'+file, '/home/yanuar/Desktop/Json/Blue/Main_Parameter/'+'Results_'+file)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.23s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.531
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.893
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.197
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.627
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/Gr.json
# Export patheval_Gr.json
# eval_Gr.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_Gr.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.26s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.796
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/10m.json
# Export patheval_10m.json
# eval_10m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_10m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.907
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.718
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/4m.json
# Export patheval_4m.json
# eval_4m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_4m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.28s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.730
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.722
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.672
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/Co.json
# Export patheval_Co.json
# eval_Co.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_Co.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.28s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.944
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.606
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/SG.json
# Export patheval_SG.json
# eval_SG.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_SG.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.27s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.888
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.586
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.888
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/6m.json
# Export patheval_6m.json
# eval_6m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_6m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.51s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.440
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.810
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/Su.json
# Export patheval_Su.json
# eval_Su.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_Su.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.54s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.895
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.663
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.548
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/Ov.json
# Export patheval_Ov.json
# eval_Ov.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_Ov.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.27s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.592
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.675
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/So.json
# Export patheval_So.json
# eval_So.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_So.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.27s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Blue/Main_Parameter
# /home/yanuar/Desktop/Json/Blue/Main_Parameter/8m.json
# Export patheval_8m.json
# eval_8m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Blue/Main_Parameter/eval_8m.json

# %%
import os
results = []
files = []
for filename in os.listdir("/home/yanuar/Desktop/Json/Org/Main_Parameter/"):
    if "Results" == filename[:7]:
        results.append(filename)
    else:
        files.append(filename)
        
for file in files:
    evaluate("/home/yanuar/Desktop/Json/Org/Main_Parameter/"+file, "/home/yanuar/Desktop/Json/Org/Main_Parameter/"+'Results_'+file)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/Gr.json
# Export patheval_Gr.json
# eval_Gr.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_Gr.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.24s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/10m.json
# Export patheval_10m.json
# eval_10m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_10m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.26s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.704
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.645
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.655
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/4m.json
# Export patheval_4m.json
# eval_4m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_4m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.30s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.619
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.752
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.771
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/Co.json
# Export patheval_Co.json
# eval_Co.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_Co.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.30s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.654
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.818
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.614
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/SG.json
# Export patheval_SG.json
# eval_SG.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_SG.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.27s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.442
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.656
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.539
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.659
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/6m.json
# Export patheval_6m.json
# eval_6m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_6m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.36s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/Su.json
# Export patheval_Su.json
# eval_Su.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_Su.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.67s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.761
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.738
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.782
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.838
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/Ov.json
# Export patheval_Ov.json
# eval_Ov.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_Ov.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.31s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.763
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.852
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.703
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/So.json
# Export patheval_So.json
# eval_So.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_So.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.26s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.440
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.616
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Org/Main_Parameter
# /home/yanuar/Desktop/Json/Org/Main_Parameter/8m.json
# Export patheval_8m.json
# eval_8m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Org/Main_Parameter/eval_8m.json

# %%
import os
results = []
files = []
for filename in os.listdir("/home/yanuar/Desktop/Json/Whole/Main_Parameter/"):
    if "Results" == filename[:7]:
        results.append(filename)
    else:
        files.append(filename)
        
for file in files:
    evaluate("/home/yanuar/Desktop/Json/Whole/Main_Parameter/"+file, "/home/yanuar/Desktop/Json/Whole/Main_Parameter/"+'Results_'+file)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/Gr.json
# Export patheval_Gr.json
# eval_Gr.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_Gr.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.50s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/10m.json
# Export patheval_10m.json
# eval_10m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_10m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.51s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.806
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.703
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.931
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.684
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/4m.json
# Export patheval_4m.json
# eval_4m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_4m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.57s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.965
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.662
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/Co.json
# Export patheval_Co.json
# eval_Co.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_Co.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.809
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.568
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.793
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/SG.json
# Export patheval_SG.json
# eval_SG.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_SG.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.55s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.490
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.563
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.773
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/6m.json
# Export patheval_6m.json
# eval_6m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_6m.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.89s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.661
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.615
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/Su.json
# Export patheval_Su.json
# eval_Su.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_Su.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.22s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.548
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.649
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.831
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/Ov.json
# Export patheval_Ov.json
# eval_Ov.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_Ov.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.58s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.860
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.651
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.855
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.901
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.538
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/So.json
# Export patheval_So.json
# eval_So.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_So.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.53s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.730
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = -1.000
# /home/yanuar/Desktop/Json/Whole/Main_Parameter
# /home/yanuar/Desktop/Json/Whole/Main_Parameter/8m.json
# Export patheval_8m.json
# eval_8m.json
# COCO evaluation results are successfully exported to /home/yanuar/Desktop/Json/Whole/Main_Parameter/eval_8m.json
