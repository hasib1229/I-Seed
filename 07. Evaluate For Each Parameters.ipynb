# %%
import os
os.getcwd()
# Out:
# '/home/yanuar/Thesis/Model/YOLOv5_Yanuar'

# %%
# arrange an instance segmentation model for test
from sahi.utils.yolov5 import (
    download_yolov5s6_model,
)

# import required functions, classes
from sahi.model import Yolov5DetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict, predict_fiftyone
from sahi.scripts.coco_evaluation import evaluate
from sahi.scripts.coco_error_analysis import analyse
from IPython.display import Image
# Out:
# 03/18/2022 11:29:42 - INFO - numexpr.utils -   Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 03/18/2022 11:29:42 - INFO - numexpr.utils -   NumExpr defaulting to 8 threads.

# %%
dataset_json_path = "data/Original-I-Seed-Photo/Artificial_Seed_Test_Set.v8i.coco/test/_annotations.coco.json"
Ov_dataset_json_path = "Results/Prediction/YOLOv5s/Progress/Annotation_Filter/Ov_6m_Co.json"
Su_dataset_json_path = "Results/Prediction/YOLOv5s/Light Condition/Annotations_LC/Su.json"
m4_dataset_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Annotations_FA/4m.json"
m6_dataset_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Annotations_FA/6m.json"
m8_dataset_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Annotations_FA/8m.json"
m10_dataset_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Annotations_FA/10m.json"
Co_dataset_json_path = "Results/Prediction/YOLOv5s/Background Type/Annotations_BT/Co.json"
Gr_dataset_json_path = "Results/Prediction/YOLOv5s/Background Type/Annotations_BT/Gr.json"
SG_dataset_json_path = "Results/Prediction/YOLOv5s/Background Type/Annotations_BT/SG.json"
So_dataset_json_path = "Results/Prediction/YOLOv5s/Background Type/Annotations_BT/So.json"

# %%
result_json_path = "runs/predict/exp31/result.json"
Ov_result_json_path = "Results/Prediction/YOLOv5s/Progress/Result_Filter/Results_Ov_6m_Co.json"
Su_result_json_path = "Results/Prediction/YOLOv5s/Light Condition/Results_LC/Results_Su.json"
m4_result_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Results_FA/Results_4m.json"
m6_result_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Results_FA/Results_6m.json"
m8_result_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Results_FA/Results_8m.json"
m10_result_json_path = "Results/Prediction/YOLOv5s/Flying Altitude/Results_FA/Results_10m.json"
Co_result_json_path = "Results/Prediction/YOLOv5s/Background Type/Results_BT/Results_Co.json"
Gr_result_json_path = "Results/Prediction/YOLOv5s/Background Type/Results_BT/Results_Gr.json"
SG_result_json_path = "Results/Prediction/YOLOv5s/Background Type/Results_BT/Results_SG.json"
So_result_json_path = "Results/Prediction/YOLOv5s/Background Type/Results_BT/Results_So.json"

# %%
evaluate(
    dataset_json_path  = dataset_json_path,
    result_json_path = result_json_path,
    type = 'bbox',
    out_dir = "runs/predict/exp31/",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.09s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.512
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.921
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.425
# ...

# %%
evaluate(
    dataset_json_path  = Ov_dataset_json_path,
    result_json_path = Ov_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.949
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.960
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.664
# ...

# %%
evaluate(
    dataset_json_path  = Su_dataset_json_path,
    result_json_path = Su_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s/Light Condition",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.97s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.325
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.216
# ...

# %%
evaluate(
    dataset_json_path  = m4_dataset_json_path,
    result_json_path = m4_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s/Flying Altitude",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.45s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.316
# ...

# %%
evaluate(
    dataset_json_path  = m6_dataset_json_path,
    result_json_path = m6_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s/Flying Altitude",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.48s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.439
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.792
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.443
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.443
# ...

# %%
evaluate(
    dataset_json_path  = m8_dataset_json_path,
    result_json_path = m8_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s/Flying Altitude",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.74s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.375
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.723
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.376
# ...

# %%
evaluate(
    dataset_json_path  = m10_dataset_json_path,
    result_json_path = m10_result_json_path,
    type = 'bbox',
    out_dir = "Results/Prediction/YOLOv5s/Flying Altitude",
    classwise = True
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.66s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.649
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=500 ] = 0.649
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=500 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.302
# ...
