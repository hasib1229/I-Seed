# %% [markdown]
# # I-Seed Model Training with YOLOv5

# %% [markdown]
# # Step 1: Install Requirements

# %%
# Codes to install required packages (No need to run it if you installed the packages)

#!git clone https://github.com/ultralytics/yolov5  # clone repo
#%cd yolov5
#%pip install -qr requirements.txt # install dependencies
#%pip install -q roboflow
#%pip install -q wandb
#%pip install -U torch sahi yolov5

# %%
# Import required packages to train I-Seed YOLOv5 model

import wandb
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.1 (NVIDIA GeForce RTX 3060 Ti)

# %%
# wandb login to monitor model training process

wandb.login()
# Out:
# wandb: Currently logged in as: sojiropopo. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Step 2: Assemble I-Seed Dataset

# %% [markdown]
# Set tiled labelled dataset yaml path

# %%
dataset = "Artificial_Seed_Chip_2.0-2/data.yaml"

# %% [markdown]
# # Step 3: Train Custom I-Seed YOLOv5 model

# %% [raw]
# Train YOLOv5 model
# Parameter information = --img: image input size; --batch: batch size; --epochs: number of epochs start from 300; --data: dataset yaml path; --weights: YOLOv5 model variant

# %%
# !python train.py --img 512 --batch 16 --epochs 600 --data $dataset --weights yolov5m.pt --cache
# Out:
# wandb: Currently logged in as: sojiropopo (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=Artificial_Seed_Chip_2.0-2/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=600, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 78 commits. Use `git pull` or `git clone git@github.com:SojiroPopo/yolov5` to update.
# YOLOv5 🚀 v6.0-122-gd885799 torch 1.10.2+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7979MiB)
#
# ...

# %% [markdown]
# ###

# %%
# Evaluate Performance


# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder

# %%
# %tensorboard dev upload --logdir \
    'runs'

# %%
directory = "Artificial_Seed_Chip_2.0-2/test"

for subdir in subdirlist:
    # !python detect.py --weights runs/train/exp26/weights/best.pt --img 512 --conf 0.4 --source $subdir --classes 0 1 --save-txt --save-conf --save-crop

# %%
# !python detect.py --weights runs/train/exp26/weights/best.pt --img 512 --conf 0.1 --source /home/yanuar/Thesis/Model/YOLOv5_Yanuar/Artificial_Seed_Chip_2.0-2/test/images --save-txt --save-conf --save-crop

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('runs/detect/exp26/*.jpg'): #assuming JPG]\\\\\\\\\\






    display(Image(filename=imageName))
    print("\n")
